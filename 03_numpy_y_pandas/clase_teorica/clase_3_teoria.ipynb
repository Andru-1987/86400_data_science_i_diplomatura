# %% [markdown]
# <a href="https://colab.research.google.com/github/Andru-1987/86400_data_science_i_diplomatura/blob/main/03_numpy_y_pandas/clase_teorica/clase_3_teoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
import sys
import random

# %%
random_numbers = [random.randint(-500_000,500_000) for _ in range(1_000_000)]

# %%
len(random_numbers)
# Out:
# 1000000

# %%
sys.getsizeof(random_numbers)
# Out:
# 8448728

# %%
random_numbers_np = np.random.randint(-500_000,500_000, 1_000_000)

# %%
len(random_numbers_np)
# Out:
# 1000000

# %%
sys.getsizeof(random_numbers_np)
# Out:
# 8000112

# %%
potenciado = []

for number in random_numbers:
    potenciado.append(number**2)

# %%
random_numbers_np ** 2
# Out:
# array([238704553476,  69460183809, 114849143236, ...,   3413948041,
#         47770659225,   7635613924])

# %%
# int + str --> fallarte

# %%
mi_primer_serie_pandas = pd.Series(random_numbers)

# %%
mi_primer_serie_pandas = mi_primer_serie_pandas.astype("int8")

# %%
mi_primer_serie_pandas.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000000 entries, 0 to 999999
# Series name: None
# Non-Null Count    Dtype
# --------------    -----
# 1000000 non-null  int8
# dtypes: int8(1)
# memory usage: 976.7 KB

# %%
mi_primer_serie_pandas.sort_values()
# Out:
# 659492   -128
# 745654   -128
# 448460   -128
# 258867   -128
# 745072   -128
#          ...
# 986827    127
# 54855     127
# 116396    127
# 202912    127
# 194746    127
# Length: 1000000, dtype: int8

# %%
mi_primer_serie_pandas.max()
# Out:
# np.int8(127)

# %%
mi_primer_serie_pandas.describe().T
# Out:
# count    1000000.000000
# mean          -0.555007
# std           73.863073
# min         -128.000000
# 25%          -64.000000
# 50%           -1.000000
# 75%           63.000000
# max          127.000000
# dtype: float64

# %%
# Supongo que quiero trabajar con edades y calificaciones

escuelita_nancy = {
    "edades" : [random.randint(1,12) for _ in range(20)],
    "calificaciones" : [random.randint(1,5) for _ in range(20)]
}

print(escuelita_nancy)
# Out:
# {'edades': [12, 11, 1, 7, 7, 7, 10, 5, 4, 2, 1, 11, 3, 5, 10, 5, 3, 3, 2, 2], 'calificaciones': [4, 1, 4, 2, 3, 2, 1, 1, 3, 2, 5, 3, 1, 5, 1, 3, 3, 4, 3, 2]}

# %%
df_escuela_nancy = pd.DataFrame(escuelita_nancy).astype("int8")

# %%
df_escuela_nancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   edades          20 non-null     int8
#  1   calificaciones  20 non-null     int8
# dtypes: int8(2)
# memory usage: 172.0 bytes

# %%
df_escuela_nancy.describe().T  # std  --> standard deviation -->
# Out:
#                 count  mean       std  min   25%  50%   75%   max
# edades           20.0  5.55  3.619756  1.0  2.75  5.0  7.75  12.0
# calificaciones   20.0  2.65  1.308877  1.0  1.75  3.0  3.25   5.0

# %%
#
df_escuela_nancy[0:9]
# Out:
#    edades  calificaciones
# 0      12               4
# 1      11               1
# 2       1               4
# 3       7               2
# 4       7               3
# 5       7               2
# 6      10               1
# 7       5               1
# 8       4               3

# %%
df_escuela_nancy.loc[0,"edades"]
# Out:
# np.int8(12)

# %%
# df_escuela_nancy.calificaciones
df_escuela_nancy["edades"]
# Out:
# 0     12
# 1     11
# 2      1
# 3      7
# 4      7
# 5      7
# 6     10
# 7      5
# 8      4
# 9      2
# 10     1
# 11    11
# 12     3
# 13     5
# 14    10
# 15     5
# 16     3
# 17     3
# 18     2
# 19     2
# Name: edades, dtype: int8

# %%
df_escuela_nancy[df_escuela_nancy.calificaciones >= 5]
# Out:
#     edades  calificaciones
# 10       1               5
# 13       5               5

# %%
df_escuela_nancy["aprobado"] = df_escuela_nancy.calificaciones >= 5

# %%
df_escuela_nancy
# Out:
#     edades  calificaciones  aprobado
# 0       12               4     False
# 1       11               1     False
# 2        1               4     False
# 3        7               2     False
# 4        7               3     False
# 5        7               2     False
# 6       10               1     False
# 7        5               1     False
# 8        4               3     False
# 9        2               2     False
# 10       1               5      True
# 11      11               3     False
# 12       3               1     False
# 13       5               5      True
# 14      10               1     False
# 15       5               3     False
# 16       3               3     False
# 17       3               4     False
# 18       2               3     False
# 19       2               2     False

# %%
df_escuela_nancy.sample(10)
# Out:
#     edades  calificaciones  aprobado
# 0       12               4     False
# 7        5               1     False
# 4        7               3     False
# 10       1               5      True
# 5        7               2     False
# 19       2               2     False
# 17       3               4     False
# 11      11               3     False
# 16       3               3     False
# 3        7               2     False

# %%
df_escuela_nancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   edades          20 non-null     int8
#  1   calificaciones  20 non-null     int8
#  2   aprobado        20 non-null     bool
# dtypes: bool(1), int8(2)
# memory usage: 192.0 bytes

# %%
df_escuela_nancy.describe(include=bool)
# Out:
#        aprobado
# count        20
# unique        2
# top       False
# freq         18

# %%
escuelita_recuperatorios = {
    "edades" : [4,12,10,9],
    "calificaciones" : [None, None, 9,8]
}

# %%
recuperatorios = pd.DataFrame(escuelita_recuperatorios)

# %%
recuperatorios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   edades          4 non-null      int64
#  1   calificaciones  2 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 196.0 bytes

# %%
calificaciones_mean = recuperatorios.calificaciones.mean()
print("promedio de calificacion\t", calificaciones_mean)
# Out:
# promedio de calificacion	 8.5

# %%
recuperatorios.calificaciones.fillna(calificaciones_mean, inplace=True)
# Out:
# /tmp/ipython-input-343432588.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   recuperatorios.calificaciones.fillna(calificaciones_mean, inplace=True)

# %%
recuperatorios
# Out:
#    edades  calificaciones
# 0       4             8.5
# 1      12             8.5
# 2      10             9.0
# 3       9             8.0

# %%
df_escuela_nancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   edades          20 non-null     int8
#  1   calificaciones  20 non-null     int8
#  2   aprobado        20 non-null     bool
# dtypes: bool(1), int8(2)
# memory usage: 192.0 bytes

# %%
recuperatorios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   edades          4 non-null      int64
#  1   calificaciones  4 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 196.0 bytes

# %%
# UNION ALL | UNION

escuelita = pd.concat([ df_escuela_nancy, recuperatorios]).reset_index(drop=True)
escuelita.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   edades          24 non-null     int64
#  1   calificaciones  24 non-null     float64
#  2   aprobado        20 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 708.0+ bytes

# %%
escuelita.groupby(["edades"])["calificaciones"].mean()
# Out:
# edades
# 1     4.500000
# 2     2.333333
# 3     2.666667
# 4     5.750000
# 5     3.000000
# 7     2.333333
# 9     8.000000
# 10    3.666667
# 11    2.000000
# 12    6.250000
# Name: calificaciones, dtype: float64

# %%
escuelita.groupby("edades").agg(
    {
        "calificaciones": ["mean","min","max","count"],
        "aprobado": "mean"
    }
)
# Out:
#        calificaciones                  aprobado
#                  mean  min  max count      mean
# edades
# 1            4.500000  4.0  5.0     2       0.5
# 2            2.333333  2.0  3.0     3       0.0
# 3            2.666667  1.0  4.0     3       0.0
# 4            5.750000  3.0  8.5     2       0.0
# 5            3.000000  1.0  5.0     3  0.333333
# 7            2.333333  2.0  3.0     3       0.0
# 9            8.000000  8.0  8.0     1       NaN
# 10           3.666667  1.0  9.0     3       0.0
# 11           2.000000  1.0  3.0     2       0.0
# 12           6.250000  4.0  8.5     2       0.0

# %% [markdown]
# - Carga de datos desde un link de un archio CSV --> GOOGLE
# - Carga por medio de un link en gihthub

# %%
google_url:str = "https://docs.google.com/spreadsheets/d/e/2PACX-1vSfywEWyUnoRSuj0n2gcu_cE4n6a6RsBuywEN2WTDg1zTMEjmUCQm7jOEvVyPehf63ijaRI-fKiqHsL/pub?gid=0&single=true&output=csv"

# %%
df_escuelita:pd.DataFrame = pd.read_csv(google_url)

# %%
df_escuelita
# Out:
#               nombre  edad  calificacion
# 0     María González    18           8.5
# 1   Carlos Rodríguez    19           7.2
# 2       Ana Martínez    17           9.1
# 3     Luis Hernández    20           6.8
# 4       Laura García    18           8.9
# 5       Javier López    19           7.5
# 6        Sofía Pérez    17           9.3
# 7      Diego Sánchez    20           6.9
# 8      Elena Ramírez    18           8.7
# 9      Miguel Torres    19           7.8
# 10     Isabel Flores    17           9.0
# 11        Pablo Díaz    20           7.1
# 12       Carmen Ruiz    18           8.4
# 13     Andrés Castro    19           7.6
# 14     Raquel Ortega    17           8.8
# 15  Fernando Morales    20           6.7
# 16    Patricia Reyes    18           8.6
# 17    Ricardo Vargas    19           7.4
# 18      Mónica Silva    17           9.2
# 19     Roberto Núñez    20           7.0

# %%
pokemon_url:str = "https://raw.githubusercontent.com/Andru-1987/csv_files_ds/refs/heads/main/Pokemon.csv"

df_pokemon:pd.DataFrame = pd.read_csv(pokemon_url)

# %%
df_pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
pokemon_clean = df_pokemon[["Name","Total","HP","Attack"]]

# %%
pokemon_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    800 non-null    object
#  1   Total   800 non-null    int64
#  2   HP      800 non-null    int64
#  3   Attack  800 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 25.1+ KB

# %%
pokemon_clean.columns = pokemon_clean.columns.str.lower()

# %%
pokemon_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    800 non-null    object
#  1   total   800 non-null    int64
#  2   hp      800 non-null    int64
#  3   attack  800 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 25.1+ KB

# %% [markdown]
# *CHALLENGE*
# _De este dataset de pokemon --> me podrian agrupar por tipo de pokeom  y darme cual la cantidad de pokemons , el valor maximo de hp y cuantos son legendarios por cada tipo_
