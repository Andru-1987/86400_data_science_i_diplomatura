# %% [markdown]
# <a href="https://colab.research.google.com/github/Andru-1987/86400_data_science_i_diplomatura/blob/main/01_transformacion_digital_en_la_industria_4.0%20/clase_practica/python_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = ['EDA','Data Wrangling','Mineria datos','Limpieza Datos','SQL','Est. Inferencial','ML','DL','IA']
y = [5,10,15,20,30,25,31,30,20]

# %%
dataframe = pd.DataFrame({
    "Conocimientos": x,
    "Frecuencia": y
})

# %%
dataframe
# Out:
#       Conocimientos  Frecuencia
# 0               EDA           5
# 1    Data Wrangling          10
# 2     Mineria datos          15
# 3    Limpieza Datos          20
# 4               SQL          30
# 5  Est. Inferencial          25
# 6                ML          31
# 7                DL          30
# 8                IA          20

# %%
plt.figure(figsize=(16, 9))
sns.set_style("darkgrid")
ax = sns.barplot(x="Conocimientos", y='Frecuencia', data=dataframe)
plt.title('Importancia de Habilidades en Data Science', fontsize=16)
plt.xlabel('Habilidad', fontsize=12)
plt.ylabel('Nivel de Importancia', fontsize=12)
# plt.xticks(rotation=45, ha='right')
plt.legend(dataframe.Conocimientos)
plt.tight_layout()


for i, v in enumerate(dataframe['Frecuencia']):
    ax.text(i, v + 0.5, str(v), ha='center', fontsize=10)

plt.show()
